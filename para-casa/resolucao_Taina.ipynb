# %% [markdown]
# <a href="https://colab.research.google.com/github/taibgoulart/DesafioControleFluxo/blob/main/para-casa/resolucao_Taina.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1 - calcular a média da temperatura da amostra

# %%
import pandas as pd

# %%
df = pd.read_csv('data_sample_RS.csv', encoding='latin-1', sep=';', on_bad_lines='skip')

# %%
df
# Out:
#              Data  Hora UTC  PRECIPITAO TOTAL. HORARIO (mm)  \
# 0      2020/08/10  1500 UTC                             0.0
# 1      2021/03/31  0200 UTC                             0.0
# 2      2022/03/25  1300 UTC                             0.0
# 3      2020/06/10  0000 UTC                             0.0
# 4      2020/08/24  2100 UTC                             0.0
# ...           ...       ...                             ...
# 99995  2020/11/19  1700 UTC                             0.0
# 99996  2021/10/04  0900 UTC                             NaN
# 99997  2021/03/08  1800 UTC                             0.0
# 99998  2020/12/07  1700 UTC                             NaN
# 99999  2021/04/06  0000 UTC                             NaN
#
#        PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# 0                                                  938.1
# 1                                                  958.1
# 2                                                  981.6
# ...

# %%
df['TEMPERATURA DO AR - BULBO SECO. HORARIA (C)'].mean()
# Out:
# 18.38594081630385

# %% [markdown]
# 2 - retirar nulos da coluna 'RADIACAO GLOBAL (Kj/m2)'

# %%
df = df.dropna(subset=['RADIACAO GLOBAL (Kj/m2)'])

# %%
df['RADIACAO GLOBAL (Kj/m2)']
# Out:
# 0        2519.2
# 2        1147.4
# 4          76.9
# 7         133.3
# 8        1874.1
#           ...
# 99992     999.3
# 99994    1264.5
# 99995    3667.8
# 99996       1.1
# 99997    2106.6
# Name: RADIACAO GLOBAL (Kj/m2), Length: 47420, dtype: float64

# %% [markdown]
# 3 - copiar o dataframe reduzindo para 3 colunas (a sua escolha) e 1000 linhas (aleatórias)

# %%
df_menor = df.sample(1001)
df_menor = df_menor.reset_index(drop=True)

# %%
df_menor
# Out:
#             Data  Hora UTC  PRECIPITAO TOTAL. HORARIO (mm)  \
# 0     2022/06/14  1200 UTC                             0.0
# 1     2022/12/31  1700 UTC                             0.0
# 2     2021/09/14  1000 UTC                             NaN
# 3     2022/02/25  1000 UTC                             0.0
# 4     2020/08/11  2100 UTC                             0.0
# ...          ...       ...                             ...
# 996   2022/11/16  1300 UTC                             0.0
# 997   2022/05/19  1500 UTC                             0.0
# 998   2022/09/14  2000 UTC                             0.0
# 999   2020/04/30  2000 UTC                             0.0
# 1000  2020/04/29  1500 UTC                             0.0
#
#       PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# 0                                                1004.7
# 1                                                 943.3
# 2                                                 938.8
# ...

# %%
df_menor[['TEMPERATURA MAXIMA NA HORA ANT. (AUT) (C)', 'VENTO. VELOCIDADE HORARIA (m/s)', 'UF']]
# Out:
#       TEMPERATURA MAXIMA NA HORA ANT. (AUT) (C)  \
# 0                                          18.3
# 1                                          16.3
# 2                                          15.0
# 3                                          11.5
# 4                                          12.2
# ...                                         ...
# 996                                        23.4
# 997                                        24.0
# 998                                        19.5
# 999                                        33.5
# 1000                                       22.2
#
#       VENTO. VELOCIDADE HORARIA (m/s)  UF
# 0                                 2.4  RS
# 1                                 1.2  RS
# 2                                 5.9  RS
# 3                                 1.9  RS
# 4                                 0.5  RS
# ...                               ...  ..
# 996                               1.9  RS
# ...
